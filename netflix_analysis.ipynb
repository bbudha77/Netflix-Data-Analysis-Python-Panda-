# %%
import pandas as pd
df = pd.read_csv("netflix_titles.csv")
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df['country'] = df['country'].fillna("Unknown")

# %%
df = df.dropna(subset = ['director'])

# %%
df.isnull().sum()
# Out:
# show_id           0
# type              0
# title             0
# director          0
# cast            473
# country           0
# date_added        0
# release_year      0
# rating            1
# duration          3
# listed_in         0
# description       0
# dtype: int64

# %%
df= df.drop_duplicates()

# %%
df.shape
# Out:
# (6173, 12)

# %%
df['cast'] = df['cast'].fillna("Unknown")

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          1
# duration        3
# listed_in       0
# description     0
# dtype: int64

# %%
df['title'].head()
# Out:
# 0                Dick Johnson Is Dead
# 2                           Ganglands
# 5                       Midnight Mass
# 6    My Little Pony: A New Generation
# 7                             Sankofa
# Name: title, dtype: object

# %%
df[['title','country','release_year']].head()
# Out:
#                               title  \
# 0              Dick Johnson Is Dead
# 2                         Ganglands
# 5                     Midnight Mass
# 6  My Little Pony: A New Generation
# 7                           Sankofa
#
#                                              country  release_year
# 0                                      United States          2020
# 2                                            Unknown          2021
# 5                                            Unknown          2021
# 6                                            Unknown          2021
# 7  United States, Ghana, Burkina Faso, United Kin...          1993

# %%
df['type'].value_counts()
# Out:
# type
# Movie      5943
# TV Show     230
# Name: count, dtype: int64

# %%
df['country'].value_counts().head(10)
# Out:
# country
# United States     2048
# India              890
# Unknown            422
# United Kingdom     212
# Canada             119
# Spain              106
# Egypt               90
# Nigeria             90
# Japan               85
# France              81
# Name: count, dtype: int64

# %%
df['rating'].value_counts().head(10)
# Out:
# rating
# TV-MA    2117
# TV-14    1457
# R         795
# TV-PG     538
# PG-13     489
# PG        286
# TV-Y7     132
# TV-G      118
# TV-Y      112
# NR         75
# Name: count, dtype: int64

# %%
df['listed_in'].value_counts().head(10)
# Out:
# listed_in
# Dramas, International Movies                        361
# Documentaries                                       334
# Stand-Up Comedy                                     309
# Comedies, Dramas, International Movies              271
# Dramas, Independent Movies, International Movies    252
# Children & Family Movies, Comedies                  196
# Children & Family Movies                            193
# Documentaries, International Movies                 179
# Dramas, International Movies, Romantic Movies       174
# Comedies, International Movies                      173
# Name: count, dtype: int64

# %%
df.sort_values(by = 'release_year', ascending = False).head(10)
# Out:
#      show_id     type                                          title  \
# 1050   s1051    Movie                                    Ride or Die
# 771     s772  TV Show  Pretty Guardian Sailor Moon Eternal The Movie
# 1281   s1282    Movie                                            Red
# 377     s378    Movie                                     Bartkowiak
# 375     s376    Movie                                 Resort to Love
# 1280   s1281    Movie                                           Pelé
# 373     s374    Movie                             The Last Mercenary
# 372     s373    Movie                 Rurouni Kenshin: The Beginning
# 1278   s1279    Movie                      Brian Regan: On the Rocks
# 363     s364    Movie                                      The Vault
#
#                          director  \
# 1050               Ryuichi Hiroki
# 771                    Chiaki Kon
# 1281             Tirumala Kishore
# 377              Daniel Markowicz
# ...

# %%
df.sort_values(by = 'title').head(10)
# Out:
#      show_id   type                          title  \
# 2036   s2037  Movie                         #Alive
# 2304   s2305  Movie  #AnneFrank - Parallel Stories
# 2481   s2482  Movie              #FriendButMarried
# 2324   s2325  Movie            #FriendButMarried 2
# 5973   s5974  Movie                          #Roxy
# 5695   s5696  Movie                      #Rucker50
# 654     s655  Movie                        #Selfie
# 655     s656  Movie                     #Selfie 69
# 5972   s5973  Movie               #cats_the_mewvie
# 5277   s5278  Movie                   #realityhigh
#
#                          director  \
# 2036                       Cho Il
# 2304  Sabina Fedeli, Anna Migotto
# 2481                Rako Prijanto
# 2324                Rako Prijanto
# 5973              Michael Kennedy
# 5695        Robert McCullough Jr.
# 654                Cristina Jacob
# 655                Cristina Jacob
# 5972             Michael Margolis
# 5277             Fernando Lebrija
#
# ...

# %%
df[(df['type']=='Movie') & (df['release_year']> 2015) & (df['country'].str.contains("India", na=False))].head()
# Out:
#     show_id   type                 title              director  \
# 105    s106  Movie      Angamaly Diaries  Lijo Jose Pellissery
# 118    s119  Movie               Gurgaon         Shanker Raman
# 126    s127  Movie               Shikara    Vidhu Vinod Chopra
# 190    s191  Movie            Thimmarusu     Sharan Koppisetty
# 203    s204  Movie  Kyaa Kool Hain Hum 3          Umesh Ghadge
#
#                                                   cast country  \
# 105  Antony Varghese, Reshma Rajan, Binny Rinky Ben...   India
# 118  Akshay Oberoi, Pankaj Tripathi, Ragini Khanna,...   India
# 126  Aadil Khan, Sadia Khateeb, Zain Khan Durrani, ...   India
# 190             Satya Dev, Priyanka Jawalkar, Brahmaji   India
# 203  Tusshar Kapoor, Aftab Shivdasani, Krishna Abhi...   India
#
#             date_added  release_year rating duration  \
# 105  September 5, 2021          2017  TV-14  128 min
# 118  September 2, 2021          2017  TV-14  106 min
# ...

# %%
df.groupby('country')['title'].count().sort_values(ascending=False).head(10)
# Out:
# country
# United States     2048
# India              890
# Unknown            422
# United Kingdom     212
# Canada             119
# Spain              106
# Nigeria             90
# Egypt               90
# Japan               85
# France              81
# Name: title, dtype: int64

# %%
df.groupby('type')['title'].count()
# Out:
# type
# Movie      5943
# TV Show     230
# Name: title, dtype: int64

# %%
df.groupby('release_year')['title'].count().sort_values(ascending=False).head(10)
# Out:
# release_year
# 2017    773
# 2018    760
# 2016    653
# 2019    629
# 2020    548
# 2015    400
# 2021    297
# 2014    267
# 2013    225
# 2012    175
# Name: title, dtype: int64

# %%
df.groupby('director')['title'].count().sort_values(ascending=False).head(10)
# Out:
# director
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Suhas Kadav               16
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          11
# Name: title, dtype: int64

# %%
df.groupby('country').agg({
'title': 'count',
'release_year': ['min', 'max']   
}).sort_values(('title','count'), ascending = False).head(10)
# Out:
#                title release_year
#                count          min   max
# country
# United States   2048         1942  2021
# India            890         1959  2021
# Unknown          422         1960  2021
# United Kingdom   212         1975  2021
# Canada           119         1998  2020
# Spain            106         2008  2021
# Nigeria           90         2003  2021
# Egypt             90         1954  2020
# Japan             85         1979  2021
# France            81         1974  2021

# %%
df.groupby('rating').agg({
'title': 'count',
'type':'nunique'  
}).sort_values('title', ascending = False)
# Out:
#           title  type
# rating
# TV-MA      2117     2
# TV-14      1457     2
# R           795     2
# TV-PG       538     2
# PG-13       489     1
# PG          286     1
# TV-Y7       132     2
# TV-G        118     2
# TV-Y        112     2
# NR           75     1
# G            41     1
# TV-Y7-FV      4     1
# UR            3     1
# NC-17         2     1
# 74 min        1     1
# 84 min        1     1
# 66 min        1     1

# %%
df.groupby(['release_year', 'type'])['title'].count().head(20)
# Out:
# release_year  type
# 1942          Movie      2
# 1943          Movie      3
# 1944          Movie      3
# 1945          Movie      3
# 1946          Movie      1
#               TV Show    1
# 1947          Movie      1
# 1954          Movie      2
# 1955          Movie      3
# 1956          Movie      2
# 1958          Movie      3
# 1959          Movie      1
# 1960          Movie      4
# 1961          Movie      1
# 1962          Movie      3
# 1963          Movie      1
# 1964          Movie      2
# 1965          Movie      2
# 1966          Movie      1
# 1967          Movie      4
# Name: title, dtype: int64

# %%
df.groupby('type')['release_year'].agg([
'min', 'max', 'mean'  
])
# Out:
#           min   max         mean
# type
# Movie    1942  2021  2013.010601
# TV Show  1946  2021  2017.573913
